# %% [markdown]
# # Module Three: Elements of Visualization
#
#
# ## Topics covered
#    - Data types: nominal, ordinal, quantitative
#    - Data models vs. Conceptual models
#    - Visual variables: position, size, color, shape, etc.
#      - characteristics of visual variables
#      - Steven's power law
#    - Efficient/effective vs. ineffective visualizations
#    - Practice and exercise
#      - bad example of visualization: scatterplots in R and Python with wrong visual variables
#      - Online: Design Test : https://www.perceptualedge.com/files/GraphDesignIQ.html
#      - ggplot2 practice: scatter plots, line graphs, bar graphs, box and whisker plots.
#
# ## Notebook Shortcuts
#
# ### Labs
# - [Elements of Visualization](labs/L3_DataViz_Elements.ipynb)
# - [Lecture Slides](labs/L3_DataViz_Elements.pdf)
#
#
# ### Practices
# - [L3 R Practice](practices/L3_R_Practice.ipynb)
# - [L3 Python Practice](practices/L3_Python_Practice.ipynb)
#
#
# ### Exercises
# - [L3 Exercise](exercises/L3_Exercise.ipynb)
#
#
#
# ## Readings and Links
# - Embedded in the lab and practice notebooks
#
#
# ## Video topics
# - **Concept Video**: Elements of Visualization
#
#
#
# ## Data Sets
# Path: `~/datasets/`
#
# * tips.txt
# * fishcatch/
# * fruitfly/
# * eyecolorgender/
#
#
# ## Suggested Schedule
#
# ### Monday
# - **Concept Video**: Elements of Visualization
# - **Lab Notebook**: L3_DataViz_Elements.ipynb
# - **Lecture Slides**: L3_DataViz_Elements.pdf
# - **Practice Notebook**: L3_R_Practice.ipynb
# - **Practice Notebook**: L3_Python_Practice.ipynb
#
#
# ### Wednesday
# - Discussion
#
# ### Thursday
# - Discussion Responses
#
# ### Friday/Saturday/Sunday
# - **Exercise**: L3_Exercise.ipynb

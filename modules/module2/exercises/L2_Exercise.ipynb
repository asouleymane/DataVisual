# %% [markdown]
# # Module 2 Color Exercise
#
# We will create plots with correct and adequate color schemes similar to the practice.

# %%
library(ggplot2)
library(RColorBrewer)

# %% [markdown]
# **Activity 1: ** Display colormaps with 7 colors from RColorBrewer library for a sequential data type with colorblind safe colors.

# %%
## Your answer for activity 1 goes here ---
display.brewer.all(n = 7,type = 'seq',colorblindFriendly = TRUE)
# Out:
# plot without title

# %% [markdown]
# **Activity 2: ** Create a colorblind safe colormap with 100 colors from the dichromat library, display their hexadecimal codes.

# %%
library(dichromat)
p <- colorRampPalette(brewer.pal(8,'Set2'))(100)
p
# Out:
#   [1] "#66C2A5" "#70BEA0" "#7BBA9B" "#85B696" "#90B392" "#9BAF8D" "#A5AB88"
#   [8] "#B0A783" "#BAA47F" "#C5A07A" "#D09C75" "#DA9870" "#E5956C" "#EF9167"
#  [15] "#FA8D62" "#F58E68" "#ED8F6F" "#E59077" "#DD927E" "#D59386" "#CE948D"
#  [22] "#C69694" "#BE979C" "#B698A3" "#AE9AAB" "#A69BB2" "#9E9CBA" "#979EC1"
#  [29] "#8F9FC8" "#919ECA" "#979DCA" "#9E9BC9" "#A49AC8" "#AB98C8" "#B197C7"
#  [36] "#B795C7" "#BE93C6" "#C492C6" "#CA90C5" "#D18FC4" "#D78DC4" "#DD8CC3"
#  [43] "#E48AC3" "#E48DBE" "#DF92B6" "#DB98AE" "#D69DA6" "#D1A39F" "#CDA897"
#  [50] "#C8AE8F" "#C4B387" "#BFB97F" "#BBBE77" "#B6C470" "#B1C968" "#ADCF60"
#  [57] "#A8D458" "#A8D852" "#AED850" "#B5D84D" "#BBD84B" "#C1D848" "#C8D845"
#  [64] "#CED843" "#D4D840" "#DBD83D" "#E1D83B" "#E7D838" "#EDD836" "#F4D833"
#  [71] "#FAD830" "#FED831" "#FCD738" "#FAD53F" "#F8D446" "#F7D24D" "#F5D154"
#  [78] "#F3CF5B" "#F1CE63" "#EFCC6A" "#EDCB71" "#ECC978" "#EAC87F" "#E8C686"
#  [85] "#E6C58D" "#E4C394" "#E0C296" "#DDC198" "#D9C09A" "#D6BF9D" "#D2BD9F"
#  [92] "#CFBCA1" "#CBBBA3" "#C8BAA5" "#C4B9A8" "#C1B7AA" "#BDB6AC" "#BAB5AE"
#  [99] "#B6B4B0" "#B3B3B3"

# %% [markdown]
# **Activity 3: ** Use ellipse library to create an elliptical correlation plot for the diamonds data using carat, price, table, and depth variables. Make sure to use a colorblind safe diverging color scheme.

# %%
library(ellipse)
head(diamonds)
data=diamonds[,c("carat","depth","price","table")]
## Your answer for activity 3 goes here --
mycolors<-colorRampPalette(brewer.pal(11,'BrBG'))(100)
datacorr<-cor(data)
ord<-order(datacorr[1,])
ord
data_ord<-datacorr[ord,ord]
data_ord
plotcorr(data_ord,col=mycolors[data_ord*50+50],mar=c(1,1,1,1))
# Out:
#   carat cut       color clarity depth table price x    y    z
# 1 0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43
# 2 0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31
# 3 0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31
# 4 0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63
# 5 0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75
# 6 0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48
# [1] 2 4 3 1
#       depth       table      price      carat
# depth  1.00000000 -0.2957785 -0.0106474 0.02822431
# table -0.29577852  1.0000000  0.1271339 0.18161755
# price -0.01064740  0.1271339  1.0000000 0.92159130
# carat  0.02822431  0.1816175  0.9215913 1.00000000
# plot without title

# %% [markdown]
# **Activity 4: ** Create a scatter plot using **all** diamonds data for carat vs. price and encode clarity variable with a sequential color scheme.

# %%
## Your answer for activity 4 goes here ---
p<-ggplot(diamonds,aes(x=carat,y=price,color=clarity))+ geom_point()
p + scale_color_brewer(type="seq",palette=8)
# Out:
# plot without title

# %% [markdown]
# **Activity 5: ** Repeat Activity 4 with alpha transparency. Is this a better idea ? Discus your answer.

# %%
## Your answer for activity 5 goes here ---
p<-ggplot(diamonds,aes(x=carat,y=price,color=clarity))+geom_point(alpha=.6)
p + scale_color_brewer(type="seq",palette=8)

# hint: geom_point(alpha=0.5)
# Out:
# plot without title

# %%
#I believe leaving R to choose a default apha transparency may be a better idea.It looks to me that
# there is a reduced color saturation and luminance when alpha is used.And one has to get the right 
# alpha value.
